# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
path = '/content/drive/MyDrive/Colab Notebooks/NIAS/Dados'
covid_data = pd.read_csv(f'{path}/covid_19_clean_complete.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
covid_data.shape
# Out:
# (49068, 10)

# %%
covid_data
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
covid_data.dtypes
# Out:
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# Date               object
# Confirmed           int64
# Deaths              int64
# Recovered           int64
# Active              int64
# WHO Region         object
# dtype: object

# %%
covid_data['Date'] = pd.to_datetime(covid_data['Date'])

# %%
covid_data.describe()
# Out:
#                 Lat          Long                 Date     Confirmed  \
# count  49068.000000  49068.000000                49068  4.906800e+04
# mean      21.433730     23.528236  2020-04-24 12:00:00  1.688490e+04
# min      -51.796300   -135.000000  2020-01-22 00:00:00  0.000000e+00
# 25%        7.873054    -15.310100  2020-03-08 18:00:00  4.000000e+00
# 50%       23.634500     21.745300  2020-04-24 12:00:00  1.680000e+02
# 75%       41.204380     80.771797  2020-06-10 06:00:00  1.518250e+03
# max       71.706900    178.065000  2020-07-27 00:00:00  4.290259e+06
# std       24.950320     70.442740                  NaN  1.273002e+05
#
#               Deaths     Recovered        Active
# count   49068.000000  4.906800e+04  4.906800e+04
# mean      884.179160  7.915713e+03  8.085012e+03
# min         0.000000  0.000000e+00 -1.400000e+01
# 25%         0.000000  0.000000e+00  0.000000e+00
# 50%         2.000000  2.900000e+01  2.600000e+01
# ...

# %%
covid_data.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %%
covid_china = covid_data[covid_data['Country/Region'] == 'China']
covid_china
# Out:
#       Province/State Country/Region      Lat      Long       Date  Confirmed  \
# 48             Anhui          China  31.8257  117.2264 2020-01-22          1
# 49           Beijing          China  40.1824  116.4142 2020-01-22         14
# 50         Chongqing          China  30.0572  107.8740 2020-01-22          6
# 51            Fujian          China  26.0789  117.9874 2020-01-22          1
# 52             Gansu          China  35.7518  104.2861 2020-01-22          0
# ...              ...            ...      ...       ...        ...        ...
# 48883        Tianjin          China  39.3054  117.3230 2020-07-27        204
# 48884          Tibet          China  31.6927   88.0924 2020-07-27          1
# 48885       Xinjiang          China  41.1129   85.2401 2020-07-27        311
# 48886         Yunnan          China  24.9740  101.4870 2020-07-27        190
# 48887       Zhejiang          China  29.1832  120.0934 2020-07-27       1270
#
# ...

# %%
covid_china = covid_china.groupby('Province/State')[['Confirmed', 'Deaths', 'Recovered', 'Active']].sum().reset_index()
covid_china
# Out:
#     Province/State  Confirmed  Deaths  Recovered   Active
# 0            Anhui     172497    1007     155768    15722
# 1          Beijing     108512    1383      83847    23282
# 2        Chongqing     101756    1013      90135    10608
# 3           Fujian      59855     159      52936     6760
# 4            Gansu      23786     341      21163     2282
# 5        Guangdong     268051    1273     237110    29668
# 6          Guangxi      44368     336      38927     5105
# 7          Guizhou      25341     335      22672     2334
# 8           Hainan      29584     993      25930     2661
# 9            Hebei      56848    1000          0    55848
# 10    Heilongjiang     131961    2196     111670    18095
# 11           Henan     222581    3628          0   218953
# 12       Hong Kong     151541     814     113725    37002
# 13           Hubei   11473248  651932    9387518  1433798
# 14           Hunan     178641     662     162439    15540
# ...

# %%
covid_china.sort_values('Confirmed', ascending=False)
# Out:
#     Province/State  Confirmed  Deaths  Recovered   Active
# 13           Hubei   11473248  651932    9387518  1433798
# 5        Guangdong     268051    1273     237110    29668
# 11           Henan     222581    3628          0   218953
# 32        Zhejiang     220824     159     198777    21888
# 14           Hunan     178641     662     162439    15540
# 0            Anhui     172497    1007     155768    15722
# 17         Jiangxi     162963     169     147655    15139
# 12       Hong Kong     151541     814     113725    37002
# 24        Shandong     132944    1103     118227    13614
# 10    Heilongjiang     131961    2196     111670    18095
# 16         Jiangsu     112469       0     102367    10102
# 1          Beijing     108512    1383      83847    23282
# 2        Chongqing     101756    1013      90135    10608
# 25        Shanghai     100089     983      86680    12426
# 27         Sichuan      98075     507      86306    11262
# ...

# %%
import numpy as np


df_covid = covid_data.copy()

df_covid['Location'] = np.where(
  covid_data['Province/State'].notna(),
  covid_data['Country/Region'] + '_' + covid_data['Province/State'],
  covid_data['Country/Region']
)

df_covid
# Out:
#       Province/State         Country/Region        Lat       Long       Date  \
# 0                NaN            Afghanistan  33.939110  67.709953 2020-01-22
# 1                NaN                Albania  41.153300  20.168300 2020-01-22
# 2                NaN                Algeria  28.033900   1.659600 2020-01-22
# 3                NaN                Andorra  42.506300   1.521800 2020-01-22
# 4                NaN                 Angola -11.202700  17.873900 2020-01-22
# ...              ...                    ...        ...        ...        ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100 2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388 2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300 2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100 2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600 2020-07-27
#
# ...

# %%
df_covid.apply('Location')
# Out:
# 0                  Afghanistan
# 1                      Albania
# 2                      Algeria
# 3                      Andorra
# 4                       Angola
#                  ...
# 49063    Sao Tome and Principe
# 49064                    Yemen
# 49065                  Comoros
# 49066               Tajikistan
# 49067                  Lesotho
# Name: Location, Length: 49068, dtype: object

# %%
df_covid.drop('Province/State', axis=1, inplace=True)
df_covid
# Out:
#               Country/Region        Lat       Long       Date  Confirmed  \
# 0                Afghanistan  33.939110  67.709953 2020-01-22          0
# 1                    Albania  41.153300  20.168300 2020-01-22          0
# 2                    Algeria  28.033900   1.659600 2020-01-22          0
# 3                    Andorra  42.506300   1.521800 2020-01-22          0
# 4                     Angola -11.202700  17.873900 2020-01-22          0
# ...                      ...        ...        ...        ...        ...
# 49063  Sao Tome and Principe   0.186400   6.613100 2020-07-27        865
# 49064                  Yemen  15.552727  48.516388 2020-07-27       1691
# 49065                Comoros -11.645500  43.333300 2020-07-27        354
# 49066             Tajikistan  38.861000  71.276100 2020-07-27       7235
# 49067                Lesotho -29.610000  28.233600 2020-07-27        505
#
#        Deaths  Recovered  Active             WHO Region               Location
# ...

# %%
df_covid.columns
# Out:
# Index(['Country/Region', 'Lat', 'Long', 'Date', 'Confirmed', 'Deaths',
#        'Recovered', 'Active', 'WHO Region', 'Location'],
#       dtype='object')

# %%
df_world = pd.read_csv(f'{path}/world_data.csv', encoding='latin1')
df_world
# Out:
#             Country  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0               USA    36303589      1845       631891         12
# 1             India    31856757       974       426785          0
# 2            Brazil    20066587         0       560801          0
# 3            Russia     6402564     22660       163301        792
# 4            France     6233876         0       112098          0
# ..              ...         ...       ...          ...        ...
# 201          Brunei         339         0            3          0
# 202         Grenada         164         0            1          0
# 203      Montserrat          21         0            1          0
# 204  Western Sahara          10         0            1          0
# 205         Vanuatu           4         0            1          0
#
#      TotalRecovered  NewRecovered  ActiveCases  Critical  TotÂ Cases/1M pop  \
# 0          29805593             0      5866105     12871             108979
# ...

# %%
df_world_filtered = df_world[['Continent', 'Country', 'Population']]
df_world_filtered
# Out:
#              Continent         Country  Population
# 0        North America             USA   333124903
# 1                 Asia           India  1394827667
# 2        South America          Brazil   214211100
# 3               Europe          Russia   146002946
# 4               Europe          France    65431537
# ..                 ...             ...         ...
# 201               Asia          Brunei      442056
# 202      North America         Grenada      113093
# 203      North America      Montserrat        4995
# 204             Africa  Western Sahara      613332
# 205  Australia/Oceania         Vanuatu      314963
#
# [206 rows x 3 columns]

# %%
df_merged = pd.merge(
    df_covid,
    df_world_filtered,
    left_on='Country/Region',
    right_on='Country',
    how='inner'
)

df_world_covid = df_merged[['Country', 'Population', 'Continent', 'Deaths']]
df_world_covid['Percent-Deaths'] = (df_world_covid['Deaths'] / df_world_covid['Population']) * 100
# Out:
# /tmp/ipython-input-1548174430.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_world_covid['Percent-Deaths'] = (df_world_covid['Deaths'] / df_world_covid['Population']) * 100

# %%
df_world_covid.sort_values('Percent-Deaths', ascending=False)
df_world_covid
# Out:
#                      Country  Population Continent  Deaths  Percent-Deaths
# 0                Afghanistan    39883491      Asia       0        0.000000
# 1                    Albania     2874357    Europe       0        0.000000
# 2                    Algeria    44714617    Africa       0        0.000000
# 3                    Andorra       77400    Europe       0        0.000000
# 4                     Angola    33977854    Africa       0        0.000000
# ...                      ...         ...       ...     ...             ...
# 37971  Sao Tome and Principe      223597    Africa      14        0.006261
# 37972                  Yemen    30541712      Asia     483        0.001581
# 37973                Comoros      889788    Africa       7        0.000787
# 37974             Tajikistan     9771036      Asia      60        0.000614
# 37975                Lesotho     2160810    Africa      12        0.000555
#
# [37976 rows x 5 columns]

# %%
df_world_continent = df_world_covid.groupby('Continent').sum().reset_index()
df_world_continent.drop('Country', axis=1, inplace=True)
df_world_continent.sort_values('Percent-Deaths', ascending=False)
# Out:
#            Continent    Population    Deaths  Percent-Deaths
# 3             Europe  261538596624  14689301       78.441809
# 5      South America   81654471836   5681838        9.122557
# 4      North America  127565193256   2666043        7.011396
# 1               Asia  574107111616   3883191        6.617409
# 0             Africa  233902072668    682067        3.004900
# 2  Australia/Oceania   41664856852     13570        0.087720
